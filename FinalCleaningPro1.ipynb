# %%
import pandas as pd

# %%
# !ls
# Out:
# Untitled.ipynb                       rt.movie_info.tsv.gz
# bom.movie_gross.csv.gz               rt.reviews.tsv.gz
# imdb.name.basics.csv.gz              tmdb.movies.csv.gz
# imdb.title.akas.csv.gz               tn.movie_budgets.csv.gz
# imdb.title.basics.csv.gz             tn_movieDataCleanedPatrick.ipynb
# imdb.title.crew.csv.gz               tn_movieInitialDataPatrick.ipynb
# imdb.title.principals.csv.gz         tn_movieInitialDataPatrickCSV.csv.gz
# imdb.title.ratings.csv.gz

# %%
tn_movie_df = pd.read_csv('tn.movie_budgets.csv.gz')

# %%
tn_movie_df["production_budget"] = tn_movie_df["production_budget"].replace('[\$\,\.]',"",regex=True).astype(int)
tn_movie_df['worldwide_gross'] = tn_movie_df["worldwide_gross"].replace('[\$\,\.]',"",regex=True).astype(int)
tn_movie_df['domestic_gross'] = tn_movie_df["domestic_gross"].replace('[\$\,\.]',"",regex=True)

# %%
tn_movie_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross  worldwide_gross omestic_gross
# 0          425000000      760507625       2776345279     760507625
# 1          410600000      241063875       1045663875     241063875
# 2          350000000       42762350        149762350      42762350
# 3          330600000      459005868       1403013963     459005868
# 4          317000000      620181382       1316721747     620181382

# %%
tn_movie_df['Profit'] = tn_movie_df['worldwide_gross'] - tn_movie_df['production_budget']
tn_movie_df['Profit']
tn_movie_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget domestic_gross  worldwide_gross omestic_gross  \
# 0             425000000      760507625       2776345279     760507625
# ...

# %%
tn_movie_df['ROI'] = tn_movie_df['worldwide_gross'] / tn_movie_df['production_budget']

# %%
tn_movie_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget domestic_gross  worldwide_gross omestic_gross  \
# 0             425000000      760507625       2776345279     760507625
# ...

# %%
tn_movie_df.rename(columns={"movie": "Movie", "production_budget": "Production Budget", "domestic_gross": "Domestic Gross", "worldwide_gross": "Worldwide Gross"})
# Out:
#       id  release_date                                        Movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       Production Budget Domestic Gross  Worldwide Gross omestic_gross  \
# 0             425000000      760507625       2776345279     760507625
# ...

# %%
tn_movie_df.isnull().sum(axis = 0)
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# omestic_gross        0
# Profit               0
# ROI                  0
# dtype: int64

# %%
tn_movie_df.drop(['id', 'release_date', 'omestic_gross'], axis=1)
# Out:
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# 4               Star Wars Ep. VIII: The Last Jedi          317000000
# ...                                           ...                ...
# 5777                                       Red 11               7000
# 5778                                    Following               6000
# 5779                Return to the Land of Wonders               5000
# 5780                         A Plague So Pleasant               1400
# 5781                            My Date With Drew               1100
#
#      domestic_gross  worldwide_gross      Profit         ROI
# 0         760507625       2776345279  2351345279    6.532577
# ...

# %%
import re

# %%
tn_movie_df['movie'] = tn_movie_df['movie'].str.replace(r'[^\w\s]+', '')

# %%
tn_movie_df
# Out:
#       id  release_date                                       movie  \
# 0      1  Dec 18, 2009                                      Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean On Stranger Tides
# 2      3   Jun 7, 2019                                Dark Phoenix
# 3      4   May 1, 2015                      Avengers Age of Ultron
# 4      5  Dec 15, 2017             Star Wars Ep VIII The Last Jedi
# ...   ..           ...                                         ...
# 5777  78  Dec 31, 2018                                      Red 11
# 5778  79   Apr 2, 1999                                   Following
# 5779  80  Jul 13, 2005               Return to the Land of Wonders
# 5780  81  Sep 29, 2015                        A Plague So Pleasant
# 5781  82   Aug 5, 2005                           My Date With Drew
#
#       production_budget domestic_gross  worldwide_gross omestic_gross  \
# 0             425000000      760507625       2776345279     760507625
# ...

# %%
tn_movie_df['Year'] = tn_movie_df['release_date'].apply(lambda x: x[-4:])
tn_movie_df
# Out:
#       id  release_date                                       movie  \
# 0      1  Dec 18, 2009                                      Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean On Stranger Tides
# 2      3   Jun 7, 2019                                Dark Phoenix
# 3      4   May 1, 2015                      Avengers Age of Ultron
# 4      5  Dec 15, 2017             Star Wars Ep VIII The Last Jedi
# ...   ..           ...                                         ...
# 5777  78  Dec 31, 2018                                      Red 11
# 5778  79   Apr 2, 1999                                   Following
# 5779  80  Jul 13, 2005               Return to the Land of Wonders
# 5780  81  Sep 29, 2015                        A Plague So Pleasant
# 5781  82   Aug 5, 2005                           My Date With Drew
#
#       production_budget domestic_gross  worldwide_gross omestic_gross  \
# 0             425000000      760507625       2776345279     760507625
# ...

# %%
h = tn_movie_df.drop(['id', 'release_date', 'omestic_gross'], axis=1)
h
# Out:
#                                            movie  production_budget  \
# 0                                         Avatar          425000000
# 1     Pirates of the Caribbean On Stranger Tides          410600000
# 2                                   Dark Phoenix          350000000
# 3                         Avengers Age of Ultron          330600000
# 4                Star Wars Ep VIII The Last Jedi          317000000
# ...                                          ...                ...
# 5777                                      Red 11               7000
# 5778                                   Following               6000
# 5779               Return to the Land of Wonders               5000
# 5780                        A Plague So Pleasant               1400
# 5781                           My Date With Drew               1100
#
#      domestic_gross  worldwide_gross      Profit         ROI  Year
# 0         760507625       2776345279  2351345279    6.532577  2009
# ...

# %%
tn_movie_df = h

# %%
tn_movie_df
# Out:
#                                            movie  production_budget  \
# 0                                         Avatar          425000000
# 1     Pirates of the Caribbean On Stranger Tides          410600000
# 2                                   Dark Phoenix          350000000
# 3                         Avengers Age of Ultron          330600000
# 4                Star Wars Ep VIII The Last Jedi          317000000
# ...                                          ...                ...
# 5777                                      Red 11               7000
# 5778                                   Following               6000
# 5779               Return to the Land of Wonders               5000
# 5780                        A Plague So Pleasant               1400
# 5781                           My Date With Drew               1100
#
#      domestic_gross  worldwide_gross      Profit         ROI  Year
# 0         760507625       2776345279  2351345279    6.532577  2009
# ...

# %%
tn_movie_df["movie"] = tn_movie_df["movie"].str.lower()

# %%
tn_movie_df
# Out:
#                                            movie  production_budget  \
# 0                                         avatar          425000000
# 1     pirates of the caribbean on stranger tides          410600000
# 2                                   dark phoenix          350000000
# 3                         avengers age of ultron          330600000
# 4                star wars ep viii the last jedi          317000000
# ...                                          ...                ...
# 5777                                      red 11               7000
# 5778                                   following               6000
# 5779               return to the land of wonders               5000
# 5780                        a plague so pleasant               1400
# 5781                           my date with drew               1100
#
#      domestic_gross  worldwide_gross      Profit         ROI  Year
# 0         760507625       2776345279  2351345279    6.532577  2009
# ...

# %%
tn_movie_df['nameYear'] = tn_movie_df['movie'] + tn_movie_df['Year']

# %%
tn_movie_df
# Out:
#                                            movie  production_budget  \
# 0                                         avatar          425000000
# 1     pirates of the caribbean on stranger tides          410600000
# 2                                   dark phoenix          350000000
# 3                         avengers age of ultron          330600000
# 4                star wars ep viii the last jedi          317000000
# ...                                          ...                ...
# 5777                                      red 11               7000
# 5778                                   following               6000
# 5779               return to the land of wonders               5000
# 5780                        a plague so pleasant               1400
# 5781                           my date with drew               1100
#
#      domestic_gross  worldwide_gross      Profit         ROI  Year  \
# 0         760507625       2776345279  2351345279    6.532577  2009
# ...

# %%
tn_movie_df = tn_movie_df.rename(columns={"movie": "Movie", "production_budget": "Production Budget", "domestic_gross": "Domestic Gross", "worldwide_gross": "Worldwide Gross"})

# %%
tn_movie_df
# Out:
#                                            Movie  Production Budget  \
# 0                                         avatar          425000000
# 1     pirates of the caribbean on stranger tides          410600000
# 2                                   dark phoenix          350000000
# 3                         avengers age of ultron          330600000
# 4                star wars ep viii the last jedi          317000000
# ...                                          ...                ...
# 5777                                      red 11               7000
# 5778                                   following               6000
# 5779               return to the land of wonders               5000
# 5780                        a plague so pleasant               1400
# 5781                           my date with drew               1100
#
#      Domestic Gross  Worldwide Gross      Profit         ROI  Year  \
# 0         760507625       2776345279  2351345279    6.532577  2009
# ...
