# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline 

movie_df = pd.read_csv('Data/Complete_CLEAN_IMDB_Data.csv')

# %%
#set how floats are displayed
pd.options.display.float_format = '{:.2f}'.format

# %%
movie_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x     tconst                    primary_title  \
# 0           0            54  tt0359950  The Secret Life of Walter Mitty
# 1           1            58  tt0365907      A Walk Among the Tombstones
# 2           2            60  tt0369610                   Jurassic World
# 3           3            62  tt0376136                    The Rum Diary
# 4           4            67  tt0383010                The Three Stooges
#
#                     original_title  start_year  runtime_minutes  \
# 0  The Secret Life of Walter Mitty        2013           114.00
# 1      A Walk Among the Tombstones        2014           114.00
# 2                   Jurassic World        2015           124.00
# 3                    The Rum Diary        2011           119.00
# 4                The Three Stooges        2012            92.00
#
#                     genres  Action  Crime  ...  Number of Votes  \
# 0   Adventure,Comedy,Drama   False  False  ...           275300
# 1       Action,Crime,Drama    True   True  ...           105116
# 2  Action,Adventure,Sci-Fi    True  False  ...           539338
# 3             Comedy,Drama   False  False  ...            94787
# 4            Comedy,Family   False  False  ...            28570
#
#    Unnamed: 0_y.1                            Movie  Production Budget  \
# 0             436  the secret life of walter mitty           91000000
# 1            2066      a walk among the tombstones           28000000
# 2              33                   jurassic world          215000000
# 3            1315                    the rum diary           45000000
# 4            1903                the three stooges           30000000
#
#    Domestic Gross_y  Worldwide Gross      Profit  ROI  Year_y  \
# 0          58236838        187861183    96861183 2.06    2013
# 1          26017685         62108587    34108587 2.22    2014
# 2         652270625       1648854864  1433854864 7.67    2015
# 3          13109815         21544732   -23455268 0.48    2011
# 4          44338224         54052249    24052249 1.80    2012
#
#                               nameYear
# 0  the secret life of walter mitty2013
# 1      a walk among the tombstones2014
# 2                   jurassic world2015
# 3                    the rum diary2011
# 4                the three stooges2012
#
# [5 rows x 52 columns]

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1163 entries, 0 to 1162
# Data columns (total 52 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1163 non-null   int64
#  1   Unnamed: 0_x       1163 non-null   int64
#  2   tconst             1163 non-null   object
#  3   primary_title      1163 non-null   object
#  4   original_title     1163 non-null   object
#  5   start_year         1163 non-null   int64
#  6   runtime_minutes    1163 non-null   float64
#  7   genres             1163 non-null   object
#  8   Action             1163 non-null   bool
#  9   Crime              1163 non-null   bool
#  10  Drama              1163 non-null   bool
#  11  Biography          1163 non-null   bool
#  12  Comedy             1163 non-null   bool
#  13  Fantasy            1163 non-null   bool
#  14  Horror             1163 non-null   bool
#  15  Thriller           1163 non-null   bool
#  16  Adventure          1163 non-null   bool
#  17  Animation          1163 non-null   bool
#  18  Documentary        1163 non-null   bool
#  19  History            1163 non-null   bool
#  20  Mystery            1163 non-null   bool
#  21  Science Fiction    1163 non-null   bool
#  22  Romance            1163 non-null   bool
#  23  Family             1163 non-null   bool
#  24  War                1163 non-null   bool
#  25  Music              1163 non-null   bool
#  26  Sport              1163 non-null   bool
#  27  Western            1163 non-null   bool
#  28  Musical            1163 non-null   bool
#  29  Adult              1163 non-null   bool
#  30  News               1163 non-null   bool
#  31  Link               1163 non-null   object
#  32  start_year_str     1163 non-null   int64
#  33  Unnamed: 0_y       1163 non-null   int64
#  34  Title              1163 non-null   object
#  35  Studio             1163 non-null   object
#  36  Domestic Gross_x   1163 non-null   float64
#  37  Foreign Gross      1042 non-null   object
#  38  Year_x             1163 non-null   int64
#  39  Clean Title        1163 non-null   object
#  40  Unnamed: 0_x.1     1163 non-null   int64
#  41  Average Rating     1163 non-null   float64
#  42  Number of Votes    1163 non-null   int64
#  43  Unnamed: 0_y.1     1163 non-null   int64
#  44  Movie              1163 non-null   object
#  45  Production Budget  1163 non-null   int64
#  46  Domestic Gross_y   1163 non-null   int64
#  47  Worldwide Gross    1163 non-null   int64
#  48  Profit             1163 non-null   int64
#  49  ROI                1163 non-null   float64
#  50  Year_y             1163 non-null   int64
#  51  nameYear           1163 non-null   object
# dtypes: bool(23), float64(4), int64(14), object(11)
# memory usage: 289.7+ KB

# %%
col_drop = ['Unnamed: 0','Unnamed: 0_x','start_year_str','Unnamed: 0_y', 'Clean Title','Unnamed: 0_x.1',
           'Unnamed: 0_y.1','Domestic Gross_x','Year_y','nameYear']

movie_df.drop(col_drop, axis = 1, inplace = True)
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1163 entries, 0 to 1162
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             1163 non-null   object
#  1   primary_title      1163 non-null   object
#  2   original_title     1163 non-null   object
#  3   start_year         1163 non-null   int64
#  4   runtime_minutes    1163 non-null   float64
#  5   genres             1163 non-null   object
#  6   Action             1163 non-null   bool
#  7   Crime              1163 non-null   bool
#  8   Drama              1163 non-null   bool
#  9   Biography          1163 non-null   bool
#  10  Comedy             1163 non-null   bool
#  11  Fantasy            1163 non-null   bool
#  12  Horror             1163 non-null   bool
#  13  Thriller           1163 non-null   bool
#  14  Adventure          1163 non-null   bool
#  15  Animation          1163 non-null   bool
#  16  Documentary        1163 non-null   bool
#  17  History            1163 non-null   bool
#  18  Mystery            1163 non-null   bool
#  19  Science Fiction    1163 non-null   bool
#  20  Romance            1163 non-null   bool
#  21  Family             1163 non-null   bool
#  22  War                1163 non-null   bool
#  23  Music              1163 non-null   bool
#  24  Sport              1163 non-null   bool
#  25  Western            1163 non-null   bool
#  26  Musical            1163 non-null   bool
#  27  Adult              1163 non-null   bool
#  28  News               1163 non-null   bool
#  29  Link               1163 non-null   object
#  30  Title              1163 non-null   object
#  31  Studio             1163 non-null   object
#  32  Foreign Gross      1042 non-null   object
#  33  Year_x             1163 non-null   int64
#  34  Average Rating     1163 non-null   float64
#  35  Number of Votes    1163 non-null   int64
#  36  Movie              1163 non-null   object
#  37  Production Budget  1163 non-null   int64
#  38  Domestic Gross_y   1163 non-null   int64
#  39  Worldwide Gross    1163 non-null   int64
#  40  Profit             1163 non-null   int64
#  41  ROI                1163 non-null   float64
# dtypes: bool(23), float64(3), int64(7), object(9)
# memory usage: 198.9+ KB

# %%
movie_df.describe()
# Out:
#        start_year  runtime_minutes  Year_x  Average Rating  Number of Votes  \
# count     1163.00          1163.00 1163.00         1163.00          1163.00
# mean      2013.71           109.39 2013.71            6.46        139507.42
# std          2.56            18.42    2.56            0.93        171064.90
# min       2010.00             0.00 2010.00            1.60             5.00
# 25%       2011.00            97.00 2011.00            5.90         35953.50
# 50%       2014.00           107.00 2014.00            6.50         83200.00
# 75%       2016.00           119.00 2016.00            7.10        174728.50
# max       2018.00           180.00 2018.00            8.80       1841066.00
#
#        Production Budget  Domestic Gross_y  Worldwide Gross        Profit  \
# count            1163.00           1163.00          1163.00       1163.00
# mean         51024298.93       66113324.41     164538068.97  113513770.04
# std          56861818.42       84945629.07     235839415.55  194985394.88
# min             27000.00              0.00          3547.00 -110450242.00
# 25%          13000000.00       14156294.50      25974862.00    5848739.00
# 50%          30000000.00       38180928.00      76235001.00   42150788.00
# 75%          65000000.00       82338281.00     195492439.50  129091448.00
# max         410600000.00      700059566.00    2048134200.00 1748134200.00
#
#           ROI
# count 1163.00
# mean     4.42
# std     13.52
# min      0.00
# 25%      1.36
# 50%      2.58
# 75%      4.41
# max    416.56

# %% [markdown]
# ## QUESTION: Makes sense to use quantiles to divide  data set? <25 = low, 25-75 = med, >75 = high ##

# %%
#confirm correlation btwn engagement and gross

x = movie_df['Average Rating']
y= movie_df['Worldwide Gross']

# %%
# x= pd.to_datetime(x)

# %%
fig, ax = plt.subplots()

ax.scatter(x,y)

# %%
#should actually do this by profit or gros....

studio_count = movie_df.groupby(['Studio']).sum().sort_values(by=['Worldwide Gross'], ascending=False)
#studio_count.head(10)

# %%
#IF RERUNING THIS CELL NEED TO RERUN ALL ABOVE FIRST
studio_count.reset_index(inplace=True)
top_ten_studios = studio_count['Studio'][:10]

# %%
top_ten_studios = top_ten_studios.tolist()
top_ten_studios
# Out:
# ['BV', 'Fox', 'Uni.', 'WB', 'Sony', 'Par.', 'WB (NL)', 'LGF', 'P/DW', 'LG/S']

# %%
movie_df[movie_df['Studio'] == 'WB ']
# Out:
# Empty DataFrame
# Columns: [tconst, primary_title, original_title, start_year, runtime_minutes, genres, Action, Crime, Drama, Biography, Comedy, Fantasy, Horror, Thriller, Adventure, Animation, Documentary, History, Mystery, Science Fiction, Romance, Family, War, Music, Sport, Western, Musical, Adult, News, Link, Title, Studio, Foreign Gross, Year_x, Average Rating, Number of Votes, Movie, Production Budget, Domestic Gross_y, Worldwide Gross, Profit, ROI]
# Index: []
#
# [0 rows x 42 columns]

# %%
movie_df.head()
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1163 entries, 0 to 1162
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             1163 non-null   object
#  1   primary_title      1163 non-null   object
#  2   original_title     1163 non-null   object
#  3   start_year         1163 non-null   int64
#  4   runtime_minutes    1163 non-null   float64
#  5   genres             1163 non-null   object
#  6   Action             1163 non-null   bool
#  7   Crime              1163 non-null   bool
#  8   Drama              1163 non-null   bool
#  9   Biography          1163 non-null   bool
#  10  Comedy             1163 non-null   bool
#  11  Fantasy            1163 non-null   bool
#  12  Horror             1163 non-null   bool
#  13  Thriller           1163 non-null   bool
#  14  Adventure          1163 non-null   bool
#  15  Animation          1163 non-null   bool
#  16  Documentary        1163 non-null   bool
#  17  History            1163 non-null   bool
#  18  Mystery            1163 non-null   bool
#  19  Science Fiction    1163 non-null   bool
#  20  Romance            1163 non-null   bool
#  21  Family             1163 non-null   bool
#  22  War                1163 non-null   bool
#  23  Music              1163 non-null   bool
#  24  Sport              1163 non-null   bool
#  25  Western            1163 non-null   bool
#  26  Musical            1163 non-null   bool
#  27  Adult              1163 non-null   bool
#  28  News               1163 non-null   bool
#  29  Link               1163 non-null   object
#  30  Title              1163 non-null   object
#  31  Studio             1163 non-null   object
#  32  Foreign Gross      1042 non-null   object
#  33  Year_x             1163 non-null   int64
#  34  Average Rating     1163 non-null   float64
#  35  Number of Votes    1163 non-null   int64
#  36  Movie              1163 non-null   object
#  37  Production Budget  1163 non-null   int64
#  38  Domestic Gross_y   1163 non-null   int64
#  39  Worldwide Gross    1163 non-null   int64
#  40  Profit             1163 non-null   int64
#  41  ROI                1163 non-null   float64
# dtypes: bool(23), float64(3), int64(7), object(9)
# memory usage: 198.9+ KB

# %%
# movie_df1 = movie_df[[str(‘genres’), str(‘Movie’), str(‘Profit’), str(‘ROI’), str(‘Year_y’)]].copy()

# %%
 movie_df['genres'] = movie_df['genres'].apply(lambda x: x.split(","))

# %%
exploded_movie_df = movie_df.explode('genres')

# %%
exploded_movie_df.head(15)
# Out:
#       tconst                    primary_title  \
# 0  tt0359950  The Secret Life of Walter Mitty
# 0  tt0359950  The Secret Life of Walter Mitty
# 0  tt0359950  The Secret Life of Walter Mitty
# 1  tt0365907      A Walk Among the Tombstones
# 1  tt0365907      A Walk Among the Tombstones
# 1  tt0365907      A Walk Among the Tombstones
# 2  tt0369610                   Jurassic World
# 2  tt0369610                   Jurassic World
# 2  tt0369610                   Jurassic World
# 3  tt0376136                    The Rum Diary
# 3  tt0376136                    The Rum Diary
# 4  tt0383010                The Three Stooges
# 4  tt0383010                The Three Stooges
# 5  tt0398286                          Tangled
# 5  tt0398286                          Tangled
#
#                     original_title  start_year  runtime_minutes     genres  \
# 0  The Secret Life of Walter Mitty        2013           114.00  Adventure
# 0  The Secret Life of Walter Mitty        2013           114.00     Comedy
# 0  The Secret Life of Walter Mitty        2013           114.00      Drama
# 1      A Walk Among the Tombstones        2014           114.00     Action
# 1      A Walk Among the Tombstones        2014           114.00      Crime
# 1      A Walk Among the Tombstones        2014           114.00      Drama
# 2                   Jurassic World        2015           124.00     Action
# 2                   Jurassic World        2015           124.00  Adventure
# 2                   Jurassic World        2015           124.00     Sci-Fi
# 3                    The Rum Diary        2011           119.00     Comedy
# 3                    The Rum Diary        2011           119.00      Drama
# 4                The Three Stooges        2012            92.00     Comedy
# 4                The Three Stooges        2012            92.00     Family
# 5                          Tangled        2010           100.00  Adventure
# 5                          Tangled        2010           100.00  Animation
#
#    Action  Crime  Drama  Biography  ...  Foreign Gross  Year_x  \
# 0   False  False   True      False  ...      129900000    2013
# 0   False  False   True      False  ...      129900000    2013
# 0   False  False   True      False  ...      129900000    2013
# 1    True   True   True      False  ...       26900000    2014
# 1    True   True   True      False  ...       26900000    2014
# 1    True   True   True      False  ...       26900000    2014
# 2    True  False  False      False  ...        1,019.4    2015
# 2    True  False  False      False  ...        1,019.4    2015
# 2    True  False  False      False  ...        1,019.4    2015
# 3   False  False   True      False  ...       10800000    2011
# 3   False  False   True      False  ...       10800000    2011
# 4   False  False  False      False  ...       10500000    2012
# 4   False  False  False      False  ...       10500000    2012
# 5   False  False  False      False  ...      391000000    2010
# 5   False  False  False      False  ...      391000000    2010
#
#    Average Rating  Number of Votes                            Movie  \
# 0            7.30           275300  the secret life of walter mitty
# 0            7.30           275300  the secret life of walter mitty
# 0            7.30           275300  the secret life of walter mitty
# 1            6.50           105116      a walk among the tombstones
# 1            6.50           105116      a walk among the tombstones
# 1            6.50           105116      a walk among the tombstones
# 2            7.00           539338                   jurassic world
# 2            7.00           539338                   jurassic world
# 2            7.00           539338                   jurassic world
# 3            6.20            94787                    the rum diary
# 3            6.20            94787                    the rum diary
# 4            5.10            28570                the three stooges
# 4            5.10            28570                the three stooges
# 5            7.80           366366                          tangled
# 5            7.80           366366                          tangled
#
#    Production Budget  Domestic Gross_y  Worldwide Gross      Profit  ROI
# 0           91000000          58236838        187861183    96861183 2.06
# 0           91000000          58236838        187861183    96861183 2.06
# 0           91000000          58236838        187861183    96861183 2.06
# 1           28000000          26017685         62108587    34108587 2.22
# 1           28000000          26017685         62108587    34108587 2.22
# 1           28000000          26017685         62108587    34108587 2.22
# 2          215000000         652270625       1648854864  1433854864 7.67
# 2          215000000         652270625       1648854864  1433854864 7.67
# 2          215000000         652270625       1648854864  1433854864 7.67
# 3           45000000          13109815         21544732   -23455268 0.48
# 3           45000000          13109815         21544732   -23455268 0.48
# 4           30000000          44338224         54052249    24052249 1.80
# 4           30000000          44338224         54052249    24052249 1.80
# 5          260000000         200821936        586477240   326477240 2.26
# 5          260000000         200821936        586477240   326477240 2.26
#
# [15 rows x 42 columns]

# %%
exploded_movie_df['Studio']
# Out:
# 0        Fox
# 0        Fox
# 0        Fox
# 1       Uni.
# 1       Uni.
#         ...
# 1161     A24
# 1161     A24
# 1162      WB
# 1162      WB
# 1162      WB
# Name: Studio, Length: 3041, dtype: object

# %%
keep_cols = ['tconst', 'primary_title' ,'original_title' , 'start_year' , 'runtime_minutes', 'genres', 
             'Year_x', 'Average Rating', 'Number of Votes' , 'Movie' ,'Production Budget', 'Domestic Gross_y',
             'Worldwide Gross' ,'Profit', 'ROI','Studio']

# %%
exploded_movie_df = exploded_movie_df[keep_cols]

# %%
exploded_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3041 entries, 0 to 1162
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             3041 non-null   object
#  1   primary_title      3041 non-null   object
#  2   original_title     3041 non-null   object
#  3   start_year         3041 non-null   int64
#  4   runtime_minutes    3041 non-null   float64
#  5   genres             3041 non-null   object
#  6   Year_x             3041 non-null   int64
#  7   Average Rating     3041 non-null   float64
#  8   Number of Votes    3041 non-null   int64
#  9   Movie              3041 non-null   object
#  10  Production Budget  3041 non-null   int64
#  11  Domestic Gross_y   3041 non-null   int64
#  12  Worldwide Gross    3041 non-null   int64
#  13  Profit             3041 non-null   int64
#  14  ROI                3041 non-null   float64
#  15  Studio             3041 non-null   object
# dtypes: float64(3), int64(7), object(6)
# memory usage: 403.9+ KB

# %%
x = movie_df['Number of Votes']
y= movie_df['Profit']

fig, ax = plt.subplots()

ax.scatter(x,y)

# %%
def category(x):
    if x < 35953:
        return "Low"
    elif x > 174729:
        return "High"
    else:
        return "Medium"

# %%
exploded_movie_df['Engagement Level'] = exploded_movie_df['Number of Votes'].apply(lambda x: category(x))

# %%
exploded_movie_df
# Out:
#          tconst                    primary_title  \
# 0     tt0359950  The Secret Life of Walter Mitty
# 0     tt0359950  The Secret Life of Walter Mitty
# 0     tt0359950  The Secret Life of Walter Mitty
# 1     tt0365907      A Walk Among the Tombstones
# 1     tt0365907      A Walk Among the Tombstones
# ...         ...                              ...
# 1161  tt7784604                       Hereditary
# 1161  tt7784604                       Hereditary
# 1162  tt7959026                         The Mule
# 1162  tt7959026                         The Mule
# 1162  tt7959026                         The Mule
#
#                        original_title  start_year  runtime_minutes     genres  \
# 0     The Secret Life of Walter Mitty        2013           114.00  Adventure
# 0     The Secret Life of Walter Mitty        2013           114.00     Comedy
# 0     The Secret Life of Walter Mitty        2013           114.00      Drama
# 1         A Walk Among the Tombstones        2014           114.00     Action
# 1         A Walk Among the Tombstones        2014           114.00      Crime
# ...                               ...         ...              ...        ...
# 1161                       Hereditary        2018           127.00     Horror
# 1161                       Hereditary        2018           127.00    Mystery
# 1162                         The Mule        2018           116.00      Crime
# 1162                         The Mule        2018           116.00      Drama
# 1162                         The Mule        2018           116.00   Thriller
#
#       Year_x  Average Rating  Number of Votes  \
# 0       2013            7.30           275300
# 0       2013            7.30           275300
# 0       2013            7.30           275300
# 1       2014            6.50           105116
# 1       2014            6.50           105116
# ...      ...             ...              ...
# 1161    2018            7.30           151571
# 1161    2018            7.30           151571
# 1162    2018            7.10            58955
# 1162    2018            7.10            58955
# 1162    2018            7.10            58955
#
#                                 Movie  Production Budget  Domestic Gross_y  \
# 0     the secret life of walter mitty           91000000          58236838
# 0     the secret life of walter mitty           91000000          58236838
# 0     the secret life of walter mitty           91000000          58236838
# 1         a walk among the tombstones           28000000          26017685
# 1         a walk among the tombstones           28000000          26017685
# ...                               ...                ...               ...
# 1161                       hereditary           10000000          44069456
# 1161                       hereditary           10000000          44069456
# 1162                         the mule           50000000         103804407
# 1162                         the mule           50000000         103804407
# 1162                         the mule           50000000         103804407
#
#       Worldwide Gross     Profit  ROI Studio Engagement Level
# 0           187861183   96861183 2.06    Fox             High
# 0           187861183   96861183 2.06    Fox             High
# 0           187861183   96861183 2.06    Fox             High
# 1            62108587   34108587 2.22   Uni.           Medium
# 1            62108587   34108587 2.22   Uni.           Medium
# ...               ...        ...  ...    ...              ...
# 1161         70133905   60133905 7.01    A24           Medium
# 1161         70133905   60133905 7.01    A24           Medium
# 1162        170857676  120857676 3.42     WB           Medium
# 1162        170857676  120857676 3.42     WB           Medium
# 1162        170857676  120857676 3.42     WB           Medium
#
# [3041 rows x 17 columns]

# %%
exploded_movie_df.reset_index(inplace=True, drop=True)

# %%
exploded_movie_df
# Out:
#          tconst                    primary_title  \
# 0     tt0359950  The Secret Life of Walter Mitty
# 1     tt0359950  The Secret Life of Walter Mitty
# 2     tt0359950  The Secret Life of Walter Mitty
# 3     tt0365907      A Walk Among the Tombstones
# 4     tt0365907      A Walk Among the Tombstones
# ...         ...                              ...
# 3036  tt7784604                       Hereditary
# 3037  tt7784604                       Hereditary
# 3038  tt7959026                         The Mule
# 3039  tt7959026                         The Mule
# 3040  tt7959026                         The Mule
#
#                        original_title  start_year  runtime_minutes     genres  \
# 0     The Secret Life of Walter Mitty        2013           114.00  Adventure
# 1     The Secret Life of Walter Mitty        2013           114.00     Comedy
# 2     The Secret Life of Walter Mitty        2013           114.00      Drama
# 3         A Walk Among the Tombstones        2014           114.00     Action
# 4         A Walk Among the Tombstones        2014           114.00      Crime
# ...                               ...         ...              ...        ...
# 3036                       Hereditary        2018           127.00     Horror
# 3037                       Hereditary        2018           127.00    Mystery
# 3038                         The Mule        2018           116.00      Crime
# 3039                         The Mule        2018           116.00      Drama
# 3040                         The Mule        2018           116.00   Thriller
#
#       Year_x  Average Rating  Number of Votes  \
# 0       2013            7.30           275300
# 1       2013            7.30           275300
# 2       2013            7.30           275300
# 3       2014            6.50           105116
# 4       2014            6.50           105116
# ...      ...             ...              ...
# 3036    2018            7.30           151571
# 3037    2018            7.30           151571
# 3038    2018            7.10            58955
# 3039    2018            7.10            58955
# 3040    2018            7.10            58955
#
#                                 Movie  Production Budget  Domestic Gross_y  \
# 0     the secret life of walter mitty           91000000          58236838
# 1     the secret life of walter mitty           91000000          58236838
# 2     the secret life of walter mitty           91000000          58236838
# 3         a walk among the tombstones           28000000          26017685
# 4         a walk among the tombstones           28000000          26017685
# ...                               ...                ...               ...
# 3036                       hereditary           10000000          44069456
# 3037                       hereditary           10000000          44069456
# 3038                         the mule           50000000         103804407
# 3039                         the mule           50000000         103804407
# 3040                         the mule           50000000         103804407
#
#       Worldwide Gross     Profit  ROI Studio Engagement Level
# 0           187861183   96861183 2.06    Fox             High
# 1           187861183   96861183 2.06    Fox             High
# 2           187861183   96861183 2.06    Fox             High
# 3            62108587   34108587 2.22   Uni.           Medium
# 4            62108587   34108587 2.22   Uni.           Medium
# ...               ...        ...  ...    ...              ...
# 3036         70133905   60133905 7.01    A24           Medium
# 3037         70133905   60133905 7.01    A24           Medium
# 3038        170857676  120857676 3.42     WB           Medium
# 3039        170857676  120857676 3.42     WB           Medium
# 3040        170857676  120857676 3.42     WB           Medium
#
# [3041 rows x 17 columns]

# %%
exploded_movie_df.groupby('genres').mean().sort_values(['ROI'])
# Out:
#              start_year  runtime_minutes  Year_x  Average Rating  \
# genres
# War             2013.00           118.42 2013.00            6.42
# Western         2012.44           120.11 2012.44            6.71
# Crime           2013.74           110.72 2013.74            6.49
# Sport           2014.00           123.04 2014.00            7.01
# Family          2012.97           105.49 2012.97            6.08
# Action          2013.92           113.69 2013.92            6.45
# History         2015.33           125.90 2015.33            7.06
# Adventure       2014.05           111.97 2014.05            6.53
# Musical         2013.00           126.75 2013.00            6.75
# Fantasy         2013.72           112.00 2013.72            6.24
# Comedy          2013.52           103.45 2013.52            6.33
# Drama           2013.75           113.77 2013.75            6.70
# Biography       2014.68           119.58 2014.68            7.07
# Sci-Fi          2014.07           116.94 2014.07            6.61
# Animation       2013.99            95.09 2013.99            6.63
# Romance         2012.85           107.01 2012.85            6.41
# Music           2013.45           111.82 2013.45            6.29
# Documentary     2012.46            79.62 2012.46            6.12
# Thriller        2013.51           107.15 2013.51            6.23
# Horror          2014.02            98.51 2014.02            5.78
# Mystery         2013.92           107.11 2013.92            6.23
#
#              Number of Votes  Production Budget  Domestic Gross_y  \
# genres
# War                 96377.25        35083333.33       32847598.50
# Western            234781.33        67611111.11       63745616.00
# Crime              133091.54        34922925.53       42641321.24
# Sport               97212.61        27695652.17       42817145.39
# Family              83658.97        71702816.90       75986032.62
# Action             198856.75        84547513.66       94588971.05
# History            122648.33        41216666.67       52740229.40
# Adventure          215489.04       110432094.59      131236697.49
# Musical             93641.25        54325000.00       64031727.00
# Fantasy            169271.82        87863000.00       82493055.03
# Comedy             110232.42        45302401.85       68201917.16
# Drama              119835.01        30441819.17       39178757.60
# Biography          127558.71        28364017.86       43967687.37
# Sci-Fi             295409.47        99452981.65      129752774.34
# Animation          137684.58       103272222.22      148654279.36
# Romance             93982.24        24927392.64       38416359.34
# Music               89593.50        20939473.68       46442048.16
# Documentary         19268.77        19338461.54       32921374.69
# Thriller           145564.40        37650190.15       51649728.11
# Horror              84488.74        23228000.00       41930534.32
# Mystery            153061.56        28206185.79       47938093.45
#
#              Worldwide Gross       Profit   ROI
# genres
# War              79324273.17  44240939.83  1.62
# Western         137547470.44  69936359.33  2.11
# Crime            90298138.66  55375213.13  2.58
# Sport            65228597.83  37532945.65  2.66
# Family          183591430.90 111888614.00  2.69
# Action          257745219.99 173197706.33  2.93
# History         107117985.57  65901318.90  3.04
# Adventure       371056808.06 260624713.46  3.31
# Musical         147269405.75  92944405.75  3.31
# Fantasy         239521242.87 151658242.87  3.36
# Comedy          154423858.09 109121456.24  3.52
# Drama            86459810.65  56017991.48  3.75
# Biography        91947682.36  63583664.50  3.79
# Sci-Fi          359785913.83 260332932.18  3.98
# Animation       409861183.32 306588961.10  3.99
# Romance          79766615.11  54839222.47  4.03
# Music           103674951.26  82735477.58  4.56
# Documentary      70460431.00  51121969.46  5.66
# Thriller        131983357.60  94333167.44  7.82
# Horror           96452809.92  73224809.92 12.42
# Mystery         112331532.17  84125346.38 12.46

# %%
studio_genre_engagement = pd.pivot_table(exploded_movie_df, values='Worldwide Gross', index=['Studio'],
                    columns=['genres'], aggfunc='count', fill_value=0)
studio_genre_engagement
# Out:
# genres   Action  Adventure  Animation  Biography  Comedy  Crime  Documentary  \
# Studio
# 3D            0          0          0          0       0      0            1
# A24           1          2          0          1       6      2            0
# ATO           0          0          0          1       1      1            0
# Affirm        0          1          0          1       0      0            0
# Alc           0          0          0          0       0      0            0
# ...         ...        ...        ...        ...     ...    ...          ...
# W/Dim.        0          0          0          0       1      0            0
# WB           49         37          9          9      39     21            0
# WB (NL)       8         10          0          0      22      8            0
# Wein.         2          1          2          9      10      5            1
# Yash          1          0          0          0       0      0            0
#
# genres   Drama  Family  Fantasy  ...  Horror  Music  Musical  Mystery  \
# Studio                           ...
# 3D           0       0        0  ...       0      0        0        0
# A24         14       0        1  ...       3      0        0        2
# ATO          0       0        0  ...       0      0        0        0
# Affirm       2       0        0  ...       0      0        0        0
# Alc          1       0        0  ...       0      0        0        1
# ...        ...     ...      ...  ...     ...    ...      ...      ...
# W/Dim.       0       0        0  ...       4      0        0        2
# WB          55       7       17  ...       5      5        0        9
# WB (NL)     12       1        6  ...       8      1        1        6
# Wein.       24       0        0  ...       0      0        0        1
# Yash         2       0        0  ...       0      0        0        0
#
# genres   Romance  Sci-Fi  Sport  Thriller  War  Western
# Studio
# 3D             0       0      0         0    0        0
# A24            4       0      0         2    0        0
# ATO            0       0      0         0    0        0
# Affirm         0       0      0         0    0        0
# Alc            0       0      0         1    0        0
# ...          ...     ...    ...       ...  ...      ...
# W/Dim.         0       2      0         1    0        0
# WB            13      13      2        11    1        0
# WB (NL)        8       1      1         5    0        0
# Wein.          8       1      1         4    0        1
# Yash           1       0      1         0    0        0
#
# [79 rows x 21 columns]

# %%
profit_genre_engagement = pd.pivot_table(exploded_movie_df, values='Worldwide Gross', index=['genres'],
                    columns=['Engagement'], aggfunc='sum', fill_value=0)
profit_genre_engagement = profit_genre_engagement[['Low','Medium','High']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-660610480981> in <module>
# ----> 1 profit_genre_engagement = pd.pivot_table(exploded_movie_df, values='Worldwide Gross', index=['genres'],
#       2                     columns=['Engagement'], aggfunc='sum', fill_value=0)
#       3 profit_genre_engagement = profit_genre_engagement[['Low','Medium','High']]
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     109         values = list(values)
#     110
# --> 111     grouped = data.groupby(keys, observed=observed)
#     112     agged = grouped.agg(aggfunc)
#     113     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'Engagement'

# %%
profit_genre_engagement = pd.pivot_table(exploded_movie_df, values='Profit', index=['genres'],
                    columns=['Engagement Level'], aggfunc='sum', fill_value=0)
profit_genre_engagement = profit_genre_engagement[['Low','Medium','High']]
profit_genre_engagement
# Out:
# Engagement Level         Low       Medium         High
# genres
# Action             358075319  11342117024  51690168175
# Adventure         2127177594  16583742121  58433995470
# Animation         1856494238  10531417681  15205094580
# Biography          338400497   1786611172   4996358755
# Comedy            3736591153  19522702500  23990296899
# Crime              329529787   3365102176   6715908105
# Documentary        421066428    243519175            0
# Drama             1596042816  10315714067  19794426295
# Family             659669830   4104221047   3180200717
# Fantasy            155573194   3033168875  11977082218
# History             82700046    923727509    970612012
# Horror            1451796218   5240315684   2460989338
# Music              151696864   1213751824   1778499460
# Musical             42527466     26584607    302665550
# Mystery            270954435   3284043250   4436910221
# Romance            448711907   5186003962   3304077394
# Sci-Fi               5155595   3520413530  24850720483
# Sport              138341146    345413959    379502645
# Thriller           605736212   5468981659  12603249283
# War                -80241256    260036802    351095732
# Western            -42103845    119303713    552227366

# %%
sequential_colors = sns.color_palette("Blues", 3)
sns.palplot(sequential_colors)

# %%
profit_genre_engagement.plot.bar(stacked=True, color=sequential_colors)
sns.set_theme()

# %%
profit_genre_engagement
# Out:
# Engagement Level  High  Low  Medium
# genres
# Action             149   43     174
# Adventure          127   43     126
# Animation           27   23      40
# Biography           24   43      45
# Comedy              82  115     236
# Crime               46   36     106
# Documentary          0   10       3
# Drama              115  166     285
# Family               8   32      31
# Fantasy             30   16      54
# History              5   10      15
# Horror              11   35      79
# Music                5   18      15
# Musical              1    1       2
# Mystery             24   16      55
# Romance             20   38     105
# Sci-Fi              61    5      43
# Sport                5   10       8
# Thriller            54   34     110
# War                  2    6       4
# Western              3    4       2

# %%
total = profit_genre_engagement.sum(axis = 1).reset_index()

total
# Out:
#          genres    0
# 0        Action  366
# 1     Adventure  296
# 2     Animation   90
# 3     Biography  112
# 4        Comedy  433
# 5         Crime  188
# 6   Documentary   13
# 7         Drama  566
# 8        Family   71
# 9       Fantasy  100
# 10      History   30
# 11       Horror  125
# 12        Music   38
# 13      Musical    4
# 14      Mystery   95
# 15      Romance  163
# 16       Sci-Fi  109
# 17        Sport   23
# 18     Thriller  198
# 19          War   12
# 20      Western    9

# %%
# bar chart 1 -> top bars (group of 'smoker=No')
high_bar = sns.barplot(x="genres",  y=0, data=total, color='darkblue')

profit_genre_engagement.reset_index(inplace=True)


#medium bar
# bottom bar ->  take only smoker=Yes values from the data
medium_b = profit_genre_engagement[['genres','Medium']]

# bar chart 2 -> bottom bars (group of 'smoker=Yes')
bar2 = sns.barplot(x="genres", y="Medium", data=medium_b, estimator=sum, ci=None,  color='blue')

low_b = profit_genre_engagement[['genres','Low']]
bar3 = sns.barplot(x='genres', y='Low', data=low_b, estimator=sum, ci=None, color='lightblue')

# %%
profit_genre_engagement.reset_index(inplace=True)
profit_genre_engagement
# Out:
# Engagement Level       genres  High  Low  Medium
# 0                      Action   149   43     174
# 1                   Adventure   127   43     126
# 2                   Animation    27   23      40
# 3                   Biography    24   43      45
# 4                      Comedy    82  115     236
# 5                       Crime    46   36     106
# 6                 Documentary     0   10       3
# 7                       Drama   115  166     285
# 8                      Family     8   32      31
# 9                     Fantasy    30   16      54
# 10                    History     5   10      15
# 11                     Horror    11   35      79
# 12                      Music     5   18      15
# 13                    Musical     1    1       2
# 14                    Mystery    24   16      55
# 15                    Romance    20   38     105
# 16                     Sci-Fi    61    5      43
# 17                      Sport     5   10       8
# 18                   Thriller    54   34     110
# 19                        War     2    6       4
# 20                    Western     3    4       2

# %%
# Out:
# Engagement Level       genres  Medium
# 0                      Action     174
# 1                   Adventure     126
# 2                   Animation      40
# 3                   Biography      45
# 4                      Comedy     236
# 5                       Crime     106
# 6                 Documentary       3
# 7                       Drama     285
# 8                      Family      31
# 9                     Fantasy      54
# 10                    History      15
# 11                     Horror      79
# 12                      Music      15
# 13                    Musical       2
# 14                    Mystery      55
# 15                    Romance     105
# 16                     Sci-Fi      43
# 17                      Sport       8
# 18                   Thriller     110
# 19                        War       4
# 20                    Western       2

# %%
x_val = profit_genre_engagement.index.to_list()
x_val
# Out:
# ['Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western']

# %%
#code from python graphs gallerty to make seabourn stacked bar

tips = sns.load_dataset("tips")
# set plot style: grey grid in the background:
sns.set(style="darkgrid")

# set the figure size
plt.figure(figsize=(14, 14))

# top bar -> sum all values(smoker=No and smoker=Yes) to find y position of the bars
total = tips.groupby('day')['total_bill'].sum().reset_index()
print(total)
# bar chart 1 -> top bars (group of 'smoker=No')
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')

# bottom bar ->  take only smoker=Yes values from the data
smoker = tips[tips.smoker=='Yes']
print(smoker)
# bar chart 2 -> bottom bars (group of 'smoker=Yes')
bar2 = sns.barplot(x="day", y="total_bill", data=smoker, estimator=sum, ci=None,  color='lightblue')

# add legend
top_bar = mpatches.Patch(color='darkblue', label='smoker = No')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])

# show the graph
plt.show()
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16
#      total_bill  tip     sex smoker  day    time  size
# 56        38.01 3.00    Male    Yes  Sat  Dinner     4
# 58        11.24 1.76    Male    Yes  Sat  Dinner     2
# 60        20.29 3.21    Male    Yes  Sat  Dinner     2
# 61        13.81 2.00    Male    Yes  Sat  Dinner     2
# 62        11.02 1.98    Male    Yes  Sat  Dinner     2
# ..          ...  ...     ...    ...  ...     ...   ...
# 234       15.53 3.00    Male    Yes  Sat  Dinner     2
# 236       12.60 1.00    Male    Yes  Sat  Dinner     2
# 237       32.83 1.17    Male    Yes  Sat  Dinner     2
# 240       27.18 2.00  Female    Yes  Sat  Dinner     2
# 241       22.67 2.00    Male    Yes  Sat  Dinner     2
#
# [93 rows x 7 columns]
