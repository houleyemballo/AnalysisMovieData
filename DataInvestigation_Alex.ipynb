# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# reminder on how to call up a  row based on single value

# %% [markdown]
# ![image.png](attachment:image.png)
#
# reminder on how to replace

# %%
# !ls
# Out:
# DataInvestigation_Alex.ipynb
# README.md
# zippedData

# %%
# !ls zippedData
# Out:
# InitialDataExploration.ipynb
# Untitled.ipynb
# bom.movie_gross.csv.gz
# imdb.name.basics.csv.gz
# imdb.title.akas.csv.gz
# imdb.title.basics.csv.gz
# imdb.title.crew.csv.gz
# imdb.title.principals.csv.gz
# imdb.title.ratings.csv.gz
# rt.movie_info.tsv.gz
# rt.reviews.tsv.gz
# tmdb.movies.csv.gz
# tn.movie_budgets.csv.gz

# %% [markdown]
# ## Importing the data into dataframes ##

# %%
import pandas as pd



movie_gross_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
imdb_name_basics_df = pd.read_csv('zippedData/imdb.name.basics.csv.gz')
imdb_title_akas_df = pd.read_csv('zippedData/imdb.title.akas.csv.gz')
imdb_title_basics_df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
imdb_title_crew_df = pd.read_csv('zippedData/imdb.title.crew.csv.gz')
imdb_title_principals_df = pd.read_csv('zippedData/imdb.title.principals.csv.gz')
imdb_title_ratings_df = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
rt_movie_info_df = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t')
rt_reviews_df = pd.read_csv('zippedData/rt.reviews.tsv.gz', delimiter = '\t', encoding='latin1')
tmdb_movies_df = pd.read_csv('zippedData/tmdb.movies.csv.gz')
tn_movie_budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')

# %% [markdown]
# ## Looking at the contents of each of the dataframes ##

# %%
movie_gross_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
movie_gross_df['year'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], dtype=int64)

# %%
movie_gross_df['studio'].value_counts()
# Out:
# IFC         166
# Uni.        147
# WB          140
# Fox         136
# Magn.       136
#            ...
# OMNI/FSR      1
# Truly         1
# UEP           1
# CLF           1
# SDS           1
# Name: studio, Length: 257, dtype: int64

# %%
imdb_name_basics_df.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
imdb_title_akas_df.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
imdb_title_basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_crew_df.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
imdb_title_crew = imdb_title_basics_df.merge(imdb_title_crew_df, how = 'inner', on = 'tconst')

# %%
imdb_title_crew.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres            directors  \
# 0        2013            175.0    Action,Crime,Drama            nm0712540
# 1        2019            114.0       Biography,Drama            nm0002411
# 2        2018            122.0                 Drama            nm0000080
# 3        2018              NaN          Comedy,Drama            nm0611531
# 4        2017             80.0  Comedy,Drama,Fantasy  nm0765384,nm0749914
#
#                                    writers
# ...

# %%
imdb_title_crew['start_year'].unique()
# Out:
# array([2013, 2019, 2018, 2017, 2012, 2010, 2011, 2015, 2021, 2016, 2014,
#        2020, 2022, 2023, 2024, 2026, 2025, 2115, 2027], dtype=int64)

# %%
imdb_title_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
#  6   directors        140417 non-null  object
#  7   writers          110261 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 10.0+ MB

# %% [markdown]
# ### Just wanted to see what the listings for future movies look like ###

# %%
movies_2022 = imdb_title_crew[imdb_title_crew['start_year'].map(lambda x: x > 2021)]

# %%
movies_2022
# Out:
#             tconst                                primary_title  \
# 821     tt10042446                  Untitled Disney Marvel Film
# 948     tt10064536                  Untitled Disney Marvel Film
# 1330    tt10108854              The Hunchback of the Lighthouse
# 2465    tt10251718                        Corazones en Llamas 5
# 2483    tt10255736                      Untitled Marvel Project
# 2765    tt10288908                           The Weary Traveler
# 2904    tt10298810             Untitled Pixar Animation Project
# 2905    tt10298840            Untitled Disney Animation Project
# 2906    tt10298848          Untitled Disney Live-Action Project
# 2947    tt10300394                      Untitled Star Wars Film
# 2948    tt10300396                      Untitled Star Wars Film
# 2949    tt10300398                      Untitled Star Wars Film
# 3008    tt10303934                          Mi Asesino Favorito
# 3014    tt10304134          Unitlted Disney Live Action Project
# ...

# %%
imdb_title_principals_df.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
imdb_title_ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
rt_movie_info_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
rt_movie_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
rt_reviews_df.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
tmdb_movies_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %% [markdown]
# Note that the rotten tomatoes data does not contain a variable that, by itself, could be used to create a link with any other datasets. Because of this the focus of the data exploration will be on the other files.

# %% [markdown]
# ## Linking TN Movie Budgets w/IMDB Data ##

# %%
tn_movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn_movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# Create a int-type column "Year" to use to create a unique ID

# %%
tn_movie_budgets_df['year'] = tn_movie_budgets_df['release_date'].apply(lambda x: x[-4:])

# %%
tn_movie_budgets_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross  year
# 0         $425,000,000   $760,507,625  $2,776,345,279  2009
# ...

# %%
tn_movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
#  6   year               5782 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 316.3+ KB

# %% [markdown]
# Creating a Unique ID in IMDB Title Basics to link with the box office

# %%
imdb_title_basics_df['str_year'] = imdb_title_basics_df['start_year'].apply(lambda x: str(x))

# %%
imdb_title_basics_df['yearName'] = imdb_title_basics_df['str_year']+imdb_title_basics_df['primary_title']

# %%
imdb_title_basics_df
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# Creating a uniqueID in the TM Movie Budgets using the same inputs as with the IMDB data

# %%
tn_movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
#  6   year               5782 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 316.3+ KB

# %%
tn_movie_budgets_df['yearName'] = tn_movie_budgets_df['year']+tn_movie_budgets_df['movie']

# %%
tn_movie_budgets_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross  year  \
# 0         $425,000,000   $760,507,625  $2,776,345,279  2009
# ...

# %% [markdown]
# _Merging the two tables_

# %%
title_box_office = pd.merge(imdb_title_basics_df, tn_movie_budgets_df, how = 'inner', on ='yearName')

# %%
title_box_office
# Out:
#          tconst                    primary_title  \
# 0     tt0249516                       Foodfight!
# 1     tt0359950  The Secret Life of Walter Mitty
# 2     tt0365907      A Walk Among the Tombstones
# 3     tt0369610                   Jurassic World
# 4     tt0376136                    The Rum Diary
# ...         ...                              ...
# 1542  tt8364368                            Crawl
# 1543  tt8408152                        Detention
# 1544  tt8632862                  Fahrenheit 11/9
# 1545  tt8852552                           Icarus
# 1546  tt9024106                        Unplanned
#
#                        original_title  start_year  runtime_minutes  \
# 0                          Foodfight!        2012             91.0
# 1     The Secret Life of Walter Mitty        2013            114.0
# 2         A Walk Among the Tombstones        2014            114.0
# 3                      Jurassic World        2015            124.0
# ...

# %% [markdown]
# This is a super messy merge where a TON of data was dropped.  Going to try lowercasing the titles/removing punctuation to get a cleaner version

# %% [markdown]
# ## Merging IMDB title with TMBD data to get ratings attached to more data ##

# %%
tmdb_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
tmdb_movies_df['year'] = tmdb_movies_df['release_date'].str[:4]

# %%
tmdb_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
#  10  year               26517 non-null  object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 2.2+ MB

# %%
tmdb_movies_df['yearName'] = tmdb_movies_df['year'] + tmdb_movies_df['title']

# %%
tmdb_movies_df
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
title_ratings = pd.merge(imdb_title_basics_df, tmdb_movies_df, how = 'inner', on ='yearName')

# %%
title_ratings
# Out:
#           tconst                               primary_title  \
# 0      tt0069049                  The Other Side of the Wind
# 1      tt0192528                               Heaven & Hell
# 2      tt0255820                           Return to Babylon
# 3      tt0315642                                       Wazir
# 4      tt0326965                                 In My Sleep
# ...          ...                                         ...
# 13077  tt9584192  A Haunting on Finn Road: The Devil's Grove
# 13078  tt9777830   John Leguizamo's Latin History for Morons
# 13079  tt9814730                                   The Flare
# 13080  tt9862978                                       Terra
# 13081  tt9914642                                   Albatross
#
#                                  original_title_x  start_year  \
# 0                      The Other Side of the Wind        2018
# 1                                  Reverse Heaven        2018
# ...

# %%
title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13082 entries, 0 to 13081
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             13082 non-null  object
#  1   primary_title      13082 non-null  object
#  2   original_title_x   13080 non-null  object
#  3   start_year         13082 non-null  int64
#  4   runtime_minutes    12756 non-null  float64
#  5   genres             13002 non-null  object
#  6   str_year           13082 non-null  object
#  7   yearName           13082 non-null  object
#  8   Unnamed: 0         13082 non-null  int64
#  9   genre_ids          13082 non-null  object
#  10  id                 13082 non-null  int64
#  11  original_language  13082 non-null  object
#  12  original_title_y   13082 non-null  object
#  13  popularity         13082 non-null  float64
#  14  release_date       13082 non-null  object
#  15  title              13082 non-null  object
# ...

# %% [markdown]
# **The above table works and doesn't dump an obscene amount of data (just a horrible amount) and has a TON of redundant columns**
